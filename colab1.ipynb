# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifk/Data-Science/blob/master/colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
pip install pandas

# %%
pip install numpy

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls "/content/gdrive/My Drive/mnist_cnn.py"
# Out:
# '/content/gdrive/My Drive/mnist_cnn.py'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
pip install -q keras

# %%
# !python3 "/content/gdrive/My Drive/mnist_cnn.py"

# %%
import pandas as pd
titanic = pd.read_csv("/content/gdrive/My Drive/Titanic.csv")
titanic.head(5)
# Out:
#    Unnamed: 0 Class     Sex    Age Survived  Freq
# 0           1   1st    Male  Child       No     0
# 1           2   2nd    Male  Child       No     0
# 2           3   3rd    Male  Child       No    35
# 3           4  Crew    Male  Child       No     0
# 4           5   1st  Female  Child       No     0

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P "/content/gdrive/My Drive"
# Out:
# --2019-09-12 11:14:06--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘/content/gdrive/My Drive/Titanic.csv’
#
# Titanic.csv         100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2019-09-12 11:14:06 (201 MB/s) - ‘/content/gdrive/My Drive/Titanic.csv’ saved [1170/1170]

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
ls
# Out:
# darknet/  gdrive/  sample_data/

# %%
cd darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# cfg	  include	LICENSE.gen   LICENSE.mit  python     src
# data	  LICENSE	LICENSE.gpl   LICENSE.v1   README.md
# examples  LICENSE.fuck	LICENSE.meta  Makefile	   scripts

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-09-12 11:28:16--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  16.9MB/s    in 15s
#
# 2019-09-12 11:28:32 (15.5 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !pip install opencv-python

# %%
pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.8.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   3.2.0
# astor                    0.8.0
# astropy                  3.0.5
# atari-py                 0.1.15
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.7.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# blis                     0.2.4
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.224
# botocore                 1.12.224
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.1
# ...

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/giraffe.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
